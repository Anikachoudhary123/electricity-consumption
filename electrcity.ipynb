# %%
import pandas as pd
df = pd.read_csv("elctricity consumption.csv")
print(df)
# Out:
#          date  units and measurement  house number  application usage hours  \
# 0   5/19/2001                      2            34                        3
# 1   5/20/2001                      3            35                        4
# 2   5/21/2001                      4            36                        5
# 3   5/22/2001                      5            37                        6
# 4   5/23/2001                      6            38                        7
# 5   5/24/2001                      7            39                        8
# 6   5/25/2001                      8            40                        9
# 7   5/26/2001                      9            41                       10
# 8   5/27/2001                     10            42                       11
# 9   5/28/2001                     11            43                       12
# 10  5/29/2001                     12            44                       13
# ...

# %%
import pandas as pd
df = pd.read_csv("elctricity consumption.csv")
df.describe()
# Out:
#        units and measurement  house number  application usage hours  \
# count              21.000000     21.000000                21.000000
# mean               12.000000     44.000000                13.000000
# std                 6.204837      6.204837                 6.204837
# min                 2.000000     34.000000                 3.000000
# 25%                 7.000000     39.000000                 8.000000
# 50%                12.000000     44.000000                13.000000
# 75%                17.000000     49.000000                18.000000
# max                22.000000     54.000000                23.000000
#
#        monthly bill
# count     21.000000
# mean    1533.333333
# std      406.612018
# min     1000.000000
# 25%     1400.000000
# 50%     1400.000000
# 75%     2000.000000
# max     2000.000000

# %%
import pandas as pd 
df = pd.read_csv("elctricity consumption.csv")
print(df.columns)
# Out:
# Index(['date', 'units and measurement', 'house number',
#        'application usage hours', 'monthly bill'],
#       dtype='str')

# %%
import pandas as pd 
df = pd.read_csv("elctricity consumption.csv")
mean_bill = df["monthly bill"].mean()
print(mean_bill)
# Out:
# 1533.3333333333333

# %%
import pandas as pd 
df = pd.read_csv("elctricity consumption.csv")
df.head()
# Out:
#         date  units and measurement  house number  application usage hours  \
# 0  5/19/2001                      2            34                        3
# 1  5/20/2001                      3            35                        4
# 2  5/21/2001                      4            36                        5
# 3  5/22/2001                      5            37                        6
# 4  5/23/2001                      6            38                        7
#
#    monthly bill
# 0          1000
# 1          1000
# 2          1000
# 3          1000
# 4          1000

# %%
import pandas as pd 
df = pd.read_csv("elctricity consumption.csv")
print(df["units and measurement"].max())
# Out:
# 22
